# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

# %%
# Set up Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Visit the Quotes to Scrape site
url = 'http://books.toscrape.com/'
browser.visit(url)

# %%
# Parse the HTML
html = browser.html
html_soup = soup(html, 'html.parser')

# %%
# Scrape the Title
title = html_soup.find('a').text
title
# Out:
# 'Books to Scrape'

# %%
# Scrape the book genres list
genres_list = html_soup.find('div', class_='side_categories')
# genres list 
lists = html_soup.find_all('a', class_='href')

for lists in genres_list:
    word = lists.text
    print(word)
# Out:
#
#                                 Books
#
#
#
#
#
#
#                                 Travel
#
#
#
#
#
#
#                                 Mystery
#
#
#
#
#
#
#                                 Historical Fiction
#
#
#
#
#
#
#                                 Sequential Art
#
#
#
#
#
#
#                                 Classics
#
#
#
#
#
#
#                                 Philosophy
#
#
#
#
#
#
#                                 Romance
#
#
#
#
#
#
#                                 Womens Fiction
#
#
#
#
#
#
#                                 Fiction
#
#
#
#
#
#
#                                 Childrens
#
#
#
#
#
#
#                                 Religion
#
#
#
#
#
#
#                                 Nonfiction
#
#
#
#
#
#
#                                 Music
#
#
#
#
#
#
#                                 Default
#
#
#
#
#
#
#                                 Science Fiction
#
#
#
#
#
#
#                                 Sports and Games
#
#
#
#
#
#
# ...

# %%
reqs = requests.get(url)
soup = soup(reqs.text,'html.parser')
#URL
urls = []
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/13/qcdyn9px7n9dzsdn0sk068t40000gn/T/ipykernel_12544/2056150404.py in <module>
# ----> 1 for link in soup.find_all('a'):
#       2     print(link.get('href'))
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/bs4/element.py in find_all(self, name, attrs, recursive, string, limit, **kwargs)
#    1887         :rtype: bs4.element.ResultSet
#    1888         """
# -> 1889         generator = self.descendants
#    1890         if not recursive:
#    1891             generator = self.children
#
# AttributeError: 'str' object has no attribute 'descendants'
